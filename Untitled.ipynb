# %%
from pylab import *

# %%
a=np.arange(-6.28,6.28)
b=np.sin(a)
plot(a,b)

# %%
a=np.arange(-6.28,6.28,0.01)
b=np.sin(a)
plot(a,b)

# %%
a=np.arange(-6.28,6.28,0.01)
b=np.sin(a)
plot(a,b)

# %%
print("Running test.py")
x = 5
print("Result is", 3 * x)
# Out:
# Running test.py
# Result is 15
