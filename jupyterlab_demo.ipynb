# %%
import astroalign as aa

# %%
from pylab import *
a=np.arange(-6.28,6.28,0.1)
b=np.sin(a)
plot(a,b)
show()

# %%
from astropy.io import fits
import os
# %matplotlib widget
import matplotlib.pyplot as plt

path=os.getcwd()+'/photometry/'
print(path)
data=fits.open(path+'bgc.fits')
image=data[0].data
mean,std=np.mean(image),np.std(image)
plt.imshow(image,cmap='gray',vmin=mean-std,vmax=mean+std)
#plt.savefig('test.pdf',format='pdf',dpi=1000,overwrite=True)
# Out:
# ...
# /home/vivek/photometry/
# <div id='807f80b3-bac9-4601-9f87-8757573c2798'></div>
# <div id='6b761ef8-a2ff-42a1-84fb-d002e17d3aea'></div>
